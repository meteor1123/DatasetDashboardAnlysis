# %% [markdown]
# # Plot the Graph for the total number of issues with different labels created and closed on every date on GitHub for SPM587SP18 issues project

# %% [markdown]
# ### Example of Issue Form Filled out

# %% [raw]
# Author: SPM587SP18
# created_at: 2018-03-31,
# labels: bug,
# State: closed,
# issue_number: 1,
# closed_at: 2017-04-06

# %% [markdown]
# ### Data Set File:  SPM587SP18issues.json

# %%
import os

import _pickle as pickle

import pandas as pd                                    # panda's nickname is pd

import numpy as np                                     # numpy as np

from pandas import DataFrame, Series                   # for convenience

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Requirement : Get the total number of issues with different labels for every date and plot them in a stacked chart

# %%
# Read the JSON file into a list of dictionaries

import json
list_of_issues_dict_data = [json.loads(line) for line in open('SPM587SP18issues.json')]

# %%
# Create the DataFrame object for the list_of_issues_dict_data object

issues_df = DataFrame(list_of_issues_dict_data)

# %%
# Sanity test: print first 10 rows in our DataFrame

issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    HSP18SCM50W  closed  2018-04-22  2018-04-20           475
# 1    HSP18SCM50W  closed  2018-04-22  2018-04-19           474
# 2    YSP18SCM40K  closed  2018-04-14  2018-04-14           472
# 3    RSP18SCM19N  closed  2018-04-14  2018-04-14           470
# 4    CSP18SCM32L  closed  2018-04-13  2018-04-13           466
# 5    RSP18SCM19N  closed  2018-04-13  2018-04-13           464
# 6    MSP18SCM65B  closed  2018-04-13  2018-04-13           461
# 7    JSP18SCM63J  closed  2018-04-13  2018-04-13           459
# 8    YSP18SCM35Z  closed  2018-04-13  2018-04-13           454
# 9    YSP18SCM40K  closed  2018-04-13  2018-04-13           452
# 10   ZSP18SCM44L  closed  2018-04-13  2018-04-13           449
# 11   DSP18SCM14S  closed  2018-04-13  2018-04-13           447
# 12   RSP18SCM25A  closed  2018-04-13  2018-04-13           445
# 13   MSP18SCM01M  closed  2018-04-13  2018-04-13           444
# 14   FSP18SCM78A  closed  2018-04-13  2018-04-13           442
# 15   HSP18SCM81C  closed  2018-04-13  2018-04-13           436
# 16   YSP18SCM71Z  closed  2018-04-13  2018-04-13           435
# 17   ASP18SCM05S  closed  2018-04-13  2018-04-13           434
# 18   PSP18SCM99P  closed  2018-04-13  2018-04-13           432
# 19   SSP18SCM41S    open        None  2018-04-13           430
# 20   VSP18SCM42K  closed  2018-04-13  2018-04-13           424
# 21   ASP18SCM05A  closed  2018-04-13  2018-04-13           422
# 22   SSP18SCM19P  closed  2018-04-13  2018-04-13           420
# 23   NSP18SCM35K  closed  2018-04-13  2018-04-13           415
# 24   PSP18SCM99P  closed  2018-04-13  2018-04-13           411
# 25   SSP18SCM10S  closed  2018-04-13  2018-04-13           410
# 26   TSP18SCM03A  closed  2018-04-13  2018-04-13           409
# 27   KSP18SCM22B  closed  2018-04-13  2018-04-13           404
# 28   PSP18SCM73A  closed  2018-04-13  2018-04-13           403
# 29   ASP18SCM22S  closed  2018-04-13  2018-04-13           401
# ..           ...     ...         ...         ...           ...
# 225  HSP18SCM69D    open        None  2018-04-09            31
# 226  HSP18SCM69D    open        None  2018-04-09            30
# 227  HSP18SCM69D    open        None  2018-04-09            29
# 228  HSP18SCM69D    open        None  2018-04-09            28
# 229  HSP18SCM69D    open        None  2018-04-09            27
# 230  HSP18SCM69D    open        None  2018-04-09            26
# 231  HSP18SCM69D    open        None  2018-04-09            25
# 232  HSP18SCM69D    open        None  2018-04-09            24
# 233  HSP18SCM69D    open        None  2018-04-09            23
# 234  HSP18SCM69D    open        None  2018-04-09            22
# 235  HSP18SCM69D    open        None  2018-04-09            21
# 236  HSP18SCM69D    open        None  2018-04-09            20
# 237  HSP18SCM69D    open        None  2018-04-09            19
# 238  HSP18SCM69D    open        None  2018-04-09            18
# 239  HSP18SCM69D    open        None  2018-04-09            17
# 240  HSP18SCM69D    open        None  2018-04-09            16
# 241  HSP18SCM69D    open        None  2018-04-09            15
# 242  HSP18SCM69D    open        None  2018-04-09            14
# 243  HSP18SCM69D    open        None  2018-04-09            13
# 244  HSP18SCM69D    open        None  2018-04-09            12
# 245  HSP18SCM69D    open        None  2018-04-09            11
# 246  HSP18SCM69D    open        None  2018-04-09            10
# 247  HSP18SCM69D    open        None  2018-04-09             9
# 248  HSP18SCM69D    open        None  2018-04-09             8
# 249  HSP18SCM69D    open        None  2018-04-09             7
# 250  HSP18SCM69D    open        None  2018-04-09             6
# 251  HSP18SCM69D    open        None  2018-04-09             5
# 252  HSP18SCM69D    open        None  2018-04-09             4
# 253   SPM587SP18  closed  2018-04-09  2018-04-08             3
# 254   SPM587SP18  closed  2018-04-06  2018-03-30             2
#
#                                                 labels
# 0    [Category:Inquiry, DetectionPhase:Field, Origi...
# 1    [Address:59 W Grand Ave Chicago IL 60654, Cate...
# 2    [Category:Inquiry, DetectionPhase:Field, Origi...
# 3    [Category:Enhancement, DetectionPhase:Testing,...
# 4    [Category:Inquiry, DetectionPhase:Field, Origi...
# 5    [Address: 2400 N Lincoln Ave Chicago IL 60614,...
# 6    [Category:Bug, DetectionPhase:Testing, Origina...
# 7                                                   []
# 8    [Category:Enhancement, DetectionPhase:Testing,...
# 9    [Address:225 S Canal St Chicago IL 60606, Cate...
# 10   [Category:Inquiry, DetectionPhase:Field, Origi...
# 11   [Category:Inquiry, DetectionPhase:Field, Origi...
# 12   [Category:Enhancement, DetectionPhase:Testing,...
# 13   [Category:Enhancement, DetectionPhase:Testing,...
# 14   [Category:Inquiry, DetectionPhase:Field, Origi...
# 15   [Category:Bug, DetectionPhase:Testing, Origina...
# 16   [Category:Enhancement, DetectionPhase:Testing,...
# 17   [Category:Enhancement, DetectionPhase:Testing,...
# 18   [Category:Enhancement, DetectionPhase:Testing,...
# 19   [Category:Enhancement, DetectionPhase:Testing,...
# 20   [Category:Inquiry, DetectionPhase:Field, Origi...
# 21   [Category:Enhancement, DetectionPhase:Testing,...
# 22   [Category:Bug, DetectionPhase:Testing, Origina...
# 23   [Category:Enhancement, DetectionPhase:Testing,...
# 24   [Category:Enhancement, DetectionPhase:Testing,...
# 25   [Category:Inquiry, DetectionPhase:Field, Origi...
# 26   [Category:Enhancement, DetectionPhase:Testing,...
# 27   [Category:Inquiry, DetectionPhase:Field, Origi...
# 28   [Category:Enhancement, DetectionPhase:Testing,...
# 29   [Category:Inquiry, DetectionPhase:Field, Origi...
# ..                                                 ...
# 225  [Address:119 NORTH WABASH, Category:Bug, Detec...
# 226  [Address:111 W JACKSON, Category:Enhancement, ...
# 227  [Address:23 S CLARK, Category:Bug, DetectionPh...
# 228  [Address:1951 N WESTERN AVE, Category:Bug, Det...
# 229  [Address:645 N MCCLURG CT, Category:Inquiry, D...
# 230  [Address:1951 N WESTERN AVE, Category:Enhancem...
# 231  [Address:645 N MCCLURG CT, Category:Bug, Detec...
# 232  [Address:600 E GRAND AVE, Category:Inquiry, De...
# 233  [Address:119 NORTH WABASH, Category:Enhancemen...
# 234  [Address:233 W JACKSON, Category:Bug, Detectio...
# 235  [Address:111 W JACKSON, Category:Inquiry, Dete...
# 236  [Address:119 NORTH WABASH, Category:Enhancemen...
# 237  [Address:119 NORTH WABASH, Category:Bug, Detec...
# 238  [Address:111 W JACKSON, Category:Inquiry, Dete...
# 239  [Address:23 S CLARK, Category:Enhancement, Det...
# 240  [Address:23 S CLARK, Category:Inquiry, Detecti...
# 241  [Address:2525 S Martin Luther King Drive, Cate...
# 242  [Address:1951 N WESTERN AVE, Category:Bug, Det...
# 243  [Address:645 N MCCLURG CT, Category:Enhancemen...
# 244  [Address:645 N MCCLURG CT, Category:Inquiry, D...
# 245  [Address:600 E GRAND AVE, Category:Bug, Detect...
# 246  [Address:233 W JACKSON, Category:Enhancement, ...
# 247  [Address:119 NORTH WABASH, Category:Enhancemen...
# 248  [Address:119 NORTH WABASH, Category:Bug, Detec...
# 249  [Address:111 W JACKSON, Category:Inquiry, Dete...
# 250  [Address:111 W JACKSON, Category:Bug, Detectio...
# 251  [Address:23 S CLARK, Category:Enhancement, Det...
# 252  [Address:23 S CLARK, Category:Enhancement, Det...
# 253  [Address:2525 S Martin Luther King Drive, Cate...
# 254  [Address:2525 S Martin Luther King Drive, Cate...
#
# [255 rows x 6 columns]

# %%
# Prepare and Clean the dataframe object

wrangled_issues_df = issues_df[['Author','State','closed_at','created_at','issue_number','labels']]
wrangled_issues_df.loc[0:len(wrangled_issues_df), 'OriginationPhase']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'DetectionPhase']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Category']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Priority']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Status']= np.NaN

# %%
for i in range(0, len(wrangled_issues_df)):
    if wrangled_issues_df.iloc[i]['labels']:
        for label in wrangled_issues_df.iloc[i]['labels']:
            label_name= (label.split(':'))[0]
            label_value= (label.split(':'))[1]
            wrangled_issues_df.loc[i, label_name]=label_value

# %%
wrangled_issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    HSP18SCM50W  closed  2018-04-22  2018-04-20           475
# 1    HSP18SCM50W  closed  2018-04-22  2018-04-19           474
# 2    YSP18SCM40K  closed  2018-04-14  2018-04-14           472
# 3    RSP18SCM19N  closed  2018-04-14  2018-04-14           470
# 4    CSP18SCM32L  closed  2018-04-13  2018-04-13           466
# 5    RSP18SCM19N  closed  2018-04-13  2018-04-13           464
# 6    MSP18SCM65B  closed  2018-04-13  2018-04-13           461
# 7    JSP18SCM63J  closed  2018-04-13  2018-04-13           459
# 8    YSP18SCM35Z  closed  2018-04-13  2018-04-13           454
# 9    YSP18SCM40K  closed  2018-04-13  2018-04-13           452
# 10   ZSP18SCM44L  closed  2018-04-13  2018-04-13           449
# 11   DSP18SCM14S  closed  2018-04-13  2018-04-13           447
# 12   RSP18SCM25A  closed  2018-04-13  2018-04-13           445
# 13   MSP18SCM01M  closed  2018-04-13  2018-04-13           444
# 14   FSP18SCM78A  closed  2018-04-13  2018-04-13           442
# 15   HSP18SCM81C  closed  2018-04-13  2018-04-13           436
# 16   YSP18SCM71Z  closed  2018-04-13  2018-04-13           435
# 17   ASP18SCM05S  closed  2018-04-13  2018-04-13           434
# 18   PSP18SCM99P  closed  2018-04-13  2018-04-13           432
# 19   SSP18SCM41S    open        None  2018-04-13           430
# 20   VSP18SCM42K  closed  2018-04-13  2018-04-13           424
# 21   ASP18SCM05A  closed  2018-04-13  2018-04-13           422
# 22   SSP18SCM19P  closed  2018-04-13  2018-04-13           420
# 23   NSP18SCM35K  closed  2018-04-13  2018-04-13           415
# 24   PSP18SCM99P  closed  2018-04-13  2018-04-13           411
# 25   SSP18SCM10S  closed  2018-04-13  2018-04-13           410
# 26   TSP18SCM03A  closed  2018-04-13  2018-04-13           409
# 27   KSP18SCM22B  closed  2018-04-13  2018-04-13           404
# 28   PSP18SCM73A  closed  2018-04-13  2018-04-13           403
# 29   ASP18SCM22S  closed  2018-04-13  2018-04-13           401
# ..           ...     ...         ...         ...           ...
# 225  HSP18SCM69D    open        None  2018-04-09            31
# 226  HSP18SCM69D    open        None  2018-04-09            30
# 227  HSP18SCM69D    open        None  2018-04-09            29
# 228  HSP18SCM69D    open        None  2018-04-09            28
# 229  HSP18SCM69D    open        None  2018-04-09            27
# 230  HSP18SCM69D    open        None  2018-04-09            26
# 231  HSP18SCM69D    open        None  2018-04-09            25
# 232  HSP18SCM69D    open        None  2018-04-09            24
# 233  HSP18SCM69D    open        None  2018-04-09            23
# 234  HSP18SCM69D    open        None  2018-04-09            22
# 235  HSP18SCM69D    open        None  2018-04-09            21
# 236  HSP18SCM69D    open        None  2018-04-09            20
# 237  HSP18SCM69D    open        None  2018-04-09            19
# 238  HSP18SCM69D    open        None  2018-04-09            18
# 239  HSP18SCM69D    open        None  2018-04-09            17
# 240  HSP18SCM69D    open        None  2018-04-09            16
# 241  HSP18SCM69D    open        None  2018-04-09            15
# 242  HSP18SCM69D    open        None  2018-04-09            14
# 243  HSP18SCM69D    open        None  2018-04-09            13
# 244  HSP18SCM69D    open        None  2018-04-09            12
# 245  HSP18SCM69D    open        None  2018-04-09            11
# 246  HSP18SCM69D    open        None  2018-04-09            10
# 247  HSP18SCM69D    open        None  2018-04-09             9
# 248  HSP18SCM69D    open        None  2018-04-09             8
# 249  HSP18SCM69D    open        None  2018-04-09             7
# 250  HSP18SCM69D    open        None  2018-04-09             6
# 251  HSP18SCM69D    open        None  2018-04-09             5
# 252  HSP18SCM69D    open        None  2018-04-09             4
# 253   SPM587SP18  closed  2018-04-09  2018-04-08             3
# 254   SPM587SP18  closed  2018-04-06  2018-03-30             2
#
#                                                 labels OriginationPhase  \
# 0    [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 1    [Address:59 W Grand Ave Chicago IL 60654, Cate...     Requirements
# 2    [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 3    [Category:Enhancement, DetectionPhase:Testing,...           Design
# 4    [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 5    [Address: 2400 N Lincoln Ave Chicago IL 60614,...     Requirements
# 6    [Category:Bug, DetectionPhase:Testing, Origina...           Design
# 7                                                   []              NaN
# 8    [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 9    [Address:225 S Canal St Chicago IL 60606, Cate...     Requirements
# 10   [Category:Inquiry, DetectionPhase:Field, Origi...            Field
# 11   [Category:Inquiry, DetectionPhase:Field, Origi...    Documentation
# 12   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 13   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 14   [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 15   [Category:Bug, DetectionPhase:Testing, Origina...           Design
# 16   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 17   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 18   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 19   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 20   [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 21   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 22   [Category:Bug, DetectionPhase:Testing, Origina...     Requirements
# 23   [Category:Enhancement, DetectionPhase:Testing,...           Design
# 24   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 25   [Category:Inquiry, DetectionPhase:Field, Origi...    Documentation
# 26   [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 27   [Category:Inquiry, DetectionPhase:Field, Origi...    Documentation
# 28   [Category:Enhancement, DetectionPhase:Testing,...           Design
# 29   [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# ..                                                 ...              ...
# 225  [Address:119 NORTH WABASH, Category:Bug, Detec...            Field
# 226  [Address:111 W JACKSON, Category:Enhancement, ...           Design
# 227  [Address:23 S CLARK, Category:Bug, DetectionPh...           Coding
# 228  [Address:1951 N WESTERN AVE, Category:Bug, Det...           Coding
# 229  [Address:645 N MCCLURG CT, Category:Inquiry, D...          Testing
# 230  [Address:1951 N WESTERN AVE, Category:Enhancem...     Requirements
# 231  [Address:645 N MCCLURG CT, Category:Bug, Detec...            Field
# 232  [Address:600 E GRAND AVE, Category:Inquiry, De...    Documentation
# 233  [Address:119 NORTH WABASH, Category:Enhancemen...           Design
# 234  [Address:233 W JACKSON, Category:Bug, Detectio...           Coding
# 235  [Address:111 W JACKSON, Category:Inquiry, Dete...          Testing
# 236  [Address:119 NORTH WABASH, Category:Enhancemen...     Requirements
# 237  [Address:119 NORTH WABASH, Category:Bug, Detec...            Field
# 238  [Address:111 W JACKSON, Category:Inquiry, Dete...    Documentation
# 239  [Address:23 S CLARK, Category:Enhancement, Det...           Design
# 240  [Address:23 S CLARK, Category:Inquiry, Detecti...           Coding
# 241  [Address:2525 S Martin Luther King Drive, Cate...            Field
# 242  [Address:1951 N WESTERN AVE, Category:Bug, Det...    Documentation
# 243  [Address:645 N MCCLURG CT, Category:Enhancemen...           Coding
# 244  [Address:645 N MCCLURG CT, Category:Inquiry, D...           Coding
# 245  [Address:600 E GRAND AVE, Category:Bug, Detect...          Testing
# 246  [Address:233 W JACKSON, Category:Enhancement, ...     Requirements
# 247  [Address:119 NORTH WABASH, Category:Enhancemen...            Field
# 248  [Address:119 NORTH WABASH, Category:Bug, Detec...            Field
# 249  [Address:111 W JACKSON, Category:Inquiry, Dete...    Documentation
# 250  [Address:111 W JACKSON, Category:Bug, Detectio...           Coding
# 251  [Address:23 S CLARK, Category:Enhancement, Det...           Design
# 252  [Address:23 S CLARK, Category:Enhancement, Det...           Coding
# 253  [Address:2525 S Martin Luther King Drive, Cate...           Design
# 254  [Address:2525 S Martin Luther King Drive, Cate...           Design
#
#     DetectionPhase     Category  Priority         Status  \
# 0            Field      Inquiry      High     inProgress
# 1           Design          Bug    Medium  pendingReview
# 2            Field      Inquiry      High     inProgress
# 3          Testing  Enhancement     Major      Completed
# 4            Field      Inquiry      High  pendingReview
# 5              NaN          Bug       NaN            NaN
# 6          Testing          Bug  Critical      Completed
# 7              NaN          NaN       NaN            NaN
# 8          Testing  Enhancement  Critical      Completed
# 9           Design          Bug    Medium       Approved
# 10           Field      Inquiry    Medium     inProgress
# 11           Field      Inquiry      High  pendingReview
# 12         Testing  Enhancement  Critical       Rejected
# 13         Testing  Enhancement     Major      Completed
# 14           Field      Inquiry      High     inProgress
# 15         Testing          Bug     Major       Approved
# 16         Testing  Enhancement  Critical       Approved
# 17         Testing  Enhancement     Major       Approved
# 18         Testing  Enhancement  Critical       Approved
# 19         Testing  Enhancement  Critical      Completed
# 20           Field      Inquiry      High     inProgress
# 21         Testing  Enhancement  Critical       Approved
# 22         Testing          Bug  Critical       Rejected
# 23         Testing  Enhancement  Critical       Approved
# 24         Testing  Enhancement  Critical       Approved
# 25           Field      Inquiry      High     inProgress
# 26         Testing  Enhancement  Critical      Completed
# 27           Field      Inquiry       NaN            NaN
# 28         Testing  Enhancement  Critical      Completed
# 29           Field      Inquiry      High     inProgress
# ..             ...          ...       ...            ...
# 225         Design          Bug       Low     inProgress
# 226         Design  Enhancement      High      Completed
# 227         Coding          Bug  Critical       Approved
# 228         Coding          Bug       Low     inProgress
# 229        Testing      Inquiry      High      Completed
# 230          Field  Enhancement  Critical       Approved
# 231         Design          Bug    Medium       Rejected
# 232         Coding      Inquiry     Major  pendingReview
# 233        Testing  Enhancement       Low     inProgress
# 234          Field          Bug      High      Completed
# 235         Design      Inquiry  Critical       Approved
# 236         Coding  Enhancement    Medium       Rejected
# 237        Testing          Bug     Major  pendingReview
# 238          Field      Inquiry       Low     inProgress
# 239         Design  Enhancement      High      Completed
# 240         Coding      Inquiry  Critical       Approved
# 241        Testing      Inquiry    Medium     inProgress
# 242         Coding          Bug       Low  pendingReview
# 243          Field  Enhancement      High      Completed
# 244          Field      Inquiry  Critical       Approved
# 245        Testing          Bug  Critical       Approved
# 246         Coding  Enhancement    Medium       Approved
# 247        Testing  Enhancement     Major       Rejected
# 248          Field          Bug     Major  pendingReview
# 249          Field      Inquiry       Low     inProgress
# 250         Coding          Bug  Critical      Completed
# 251         Design  Enhancement      High      Completed
# 252         Coding  Enhancement  Critical       Approved
# 253        Testing          Bug  Critical       Rejected
# 254        Testing          Bug  Critical       Rejected
#
#                                   Address   Latitude   Longitude Address   \
# 0                                     NaN        NaN         NaN      NaN
# 1         59 W Grand Ave Chicago IL 60654        NaN         NaN      NaN
# 2                                     NaN        NaN         NaN      NaN
# 3                                     NaN        NaN         NaN      NaN
# 4                                     NaN        NaN         NaN      NaN
# 5     2400 N Lincoln Ave Chicago IL 60614  41.925573  -87.649249      NaN
# 6                                     NaN        NaN         NaN      NaN
# 7                                     NaN        NaN         NaN      NaN
# 8                                     NaN        NaN         NaN      NaN
# 9         225 S Canal St Chicago IL 60606  41.878693  -87.638924      NaN
# 10                                    NaN        NaN         NaN      NaN
# 11                                    NaN        NaN         NaN      NaN
# 12                                    NaN        NaN         NaN      NaN
# 13                                    NaN        NaN         NaN      NaN
# 14                                    NaN        NaN         NaN      NaN
# 15                                    NaN        NaN         NaN      NaN
# 16                                    NaN        NaN         NaN      NaN
# 17                                    NaN        NaN         NaN      NaN
# 18                                    NaN        NaN         NaN      NaN
# 19                                    NaN        NaN         NaN      NaN
# 20                                    NaN        NaN         NaN      NaN
# 21                                    NaN        NaN         NaN      NaN
# 22                                    NaN        NaN         NaN      NaN
# 23                                    NaN        NaN         NaN      NaN
# 24                                    NaN        NaN         NaN      NaN
# 25                                    NaN        NaN         NaN      NaN
# 26                                    NaN        NaN         NaN      NaN
# 27                                    NaN        NaN         NaN      NaN
# 28                                    NaN        NaN         NaN      NaN
# 29                                    NaN        NaN         NaN      NaN
# ..                                    ...        ...         ...      ...
# 225                      119 NORTH WABASH  41.883772  -87.625962      NaN
# 226                         111 W JACKSON  41.877817  -87.631247      NaN
# 227                            23 S CLARK  41.880982  -87.630553      NaN
# 228                    1951 N WESTERN AVE  41.917164  -87.686965      NaN
# 229                      645 N MCCLURG CT  41.893230  -87.617419      NaN
# 230                    1951 N WESTERN AVE  41.917164  -87.686965      NaN
# 231                      645 N MCCLURG CT  41.893230  -87.617419      NaN
# 232                       600 E GRAND AVE  41.891551  -87.607375      NaN
# 233                      119 NORTH WABASH  41.883772  -87.625962      NaN
# 234                         233 W JACKSON  40.170101  -92.177847      NaN
# 235                         111 W JACKSON  41.877817  -87.631247      NaN
# 236                      119 NORTH WABASH  41.883772  -87.625962      NaN
# 237                      119 NORTH WABASH  41.883772  -87.625962      NaN
# 238                         111 W JACKSON  41.877817  -87.631247      NaN
# 239                            23 S CLARK  41.880982  -87.630553      NaN
# 240                            23 S CLARK  41.880982  -87.630553      NaN
# 241       2525 S Martin Luther King Drive  41.853136  -87.633160      NaN
# 242                    1951 N WESTERN AVE  41.917164  -87.686965      NaN
# 243                      645 N MCCLURG CT  41.893230  -87.617419      NaN
# 244                      645 N MCCLURG CT  41.893230         NaN      NaN
# 245                       600 E GRAND AVE  41.891551  -87.607375      NaN
# 246                         233 W JACKSON  40.170101  -92.177847      NaN
# 247                      119 NORTH WABASH  41.883772  -87.625962      NaN
# 248                      119 NORTH WABASH  41.883772  -87.625962      NaN
# 249                         111 W JACKSON  41.877817  -87.631247      NaN
# 250                         111 W JACKSON  41.877817  -87.631247      NaN
# 251                            23 S CLARK  41.880982  -87.630553      NaN
# 252                            23 S CLARK  41.880982  -87.630553      NaN
# 253       2525 S Martin Luther King Drive  41.853136  -87.633160      NaN
# 254       2525 S Martin Luther King Drive  41.853136  -87.633160      NaN
#
#     latitude longitude Lattitude Latitude  Longitude
# 0        NaN       NaN       NaN       NaN        NaN
# 1        NaN       NaN       NaN       NaN        NaN
# 2        NaN       NaN       NaN       NaN        NaN
# 3        NaN       NaN       NaN       NaN        NaN
# 4        NaN       NaN       NaN       NaN        NaN
# 5        NaN       NaN       NaN       NaN        NaN
# 6        NaN       NaN       NaN       NaN        NaN
# 7        NaN       NaN       NaN       NaN        NaN
# 8        NaN       NaN       NaN       NaN        NaN
# 9        NaN       NaN       NaN       NaN        NaN
# 10       NaN       NaN       NaN       NaN        NaN
# 11       NaN       NaN       NaN       NaN        NaN
# 12       NaN       NaN       NaN       NaN        NaN
# 13       NaN       NaN       NaN       NaN        NaN
# 14       NaN       NaN       NaN       NaN        NaN
# 15       NaN       NaN       NaN       NaN        NaN
# 16       NaN       NaN       NaN       NaN        NaN
# 17       NaN       NaN       NaN       NaN        NaN
# 18       NaN       NaN       NaN       NaN        NaN
# 19       NaN       NaN       NaN       NaN        NaN
# 20       NaN       NaN       NaN       NaN        NaN
# 21       NaN       NaN       NaN       NaN        NaN
# 22       NaN       NaN       NaN       NaN        NaN
# 23       NaN       NaN       NaN       NaN        NaN
# 24       NaN       NaN       NaN       NaN        NaN
# 25       NaN       NaN       NaN       NaN        NaN
# 26       NaN       NaN       NaN       NaN        NaN
# 27       NaN       NaN       NaN       NaN        NaN
# 28       NaN       NaN       NaN       NaN        NaN
# 29       NaN       NaN       NaN       NaN        NaN
# ..       ...       ...       ...       ...        ...
# 225      NaN       NaN       NaN       NaN        NaN
# 226      NaN       NaN       NaN       NaN        NaN
# 227      NaN       NaN       NaN       NaN        NaN
# 228      NaN       NaN       NaN       NaN        NaN
# 229      NaN       NaN       NaN       NaN        NaN
# 230      NaN       NaN       NaN       NaN        NaN
# 231      NaN       NaN       NaN       NaN        NaN
# 232      NaN       NaN       NaN       NaN        NaN
# 233      NaN       NaN       NaN       NaN        NaN
# 234      NaN       NaN       NaN       NaN        NaN
# 235      NaN       NaN       NaN       NaN        NaN
# 236      NaN       NaN       NaN       NaN        NaN
# 237      NaN       NaN       NaN       NaN        NaN
# 238      NaN       NaN       NaN       NaN        NaN
# 239      NaN       NaN       NaN       NaN        NaN
# 240      NaN       NaN       NaN       NaN        NaN
# 241      NaN       NaN       NaN       NaN        NaN
# 242      NaN       NaN       NaN       NaN        NaN
# 243      NaN       NaN       NaN       NaN        NaN
# 244      NaN       NaN       NaN       NaN        NaN
# 245      NaN       NaN       NaN       NaN        NaN
# 246      NaN       NaN       NaN       NaN        NaN
# 247      NaN       NaN       NaN       NaN        NaN
# 248      NaN       NaN       NaN       NaN        NaN
# 249      NaN       NaN       NaN       NaN        NaN
# 250      NaN       NaN       NaN       NaN        NaN
# 251      NaN       NaN       NaN       NaN        NaN
# 252      NaN       NaN       NaN       NaN        NaN
# 253      NaN       NaN       NaN       NaN        NaN
# 254      NaN       NaN       NaN       NaN        NaN
#
# [255 rows x 20 columns]

# %%
# Plot in Bar Chart the total number of issues created every day for every Detaction Phase

LabelsReviewedByDate = wrangled_issues_df.groupby(['created_at','DetectionPhase']).created_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False)

# %%
# Plot in Bar Chart the total number of issues created for every Phase based on thier priorites

LabelsReviewedByDate = wrangled_issues_df.groupby(['Priority','DetectionPhase']).created_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False)

# %%
# Plot in Bar Chart the total number of issues closed every day for every Category

LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','Category']).closed_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red'], grid=False)

# %% [markdown]
# #  Requirement #1: Plot in Bar Chart the total number of issues closed every day for every Origination Phase

# %%
# Requirement #1: Add your code here
# updated by Huang, Silin ID: A20383068
LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','OriginationPhase']).closed_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'green', 'red', 'yellow'], grid=False)

# %% [markdown]
# #  Requirement #2: # Plot in Bar Chart the total number of issues created for every Phase based on their Status

# %%
# Requirement #2: Add your code here
# updated by Huang, Silin ID: A20383068
LabelsReviewedByDate = wrangled_issues_df.groupby(['Status', 'OriginationPhase']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'green', 'red', 'yellow'], grid=False)
